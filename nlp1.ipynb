# %% [markdown]
# <a href="https://colab.research.google.com/github/Meenalbagare/File-Transfer/blob/main/nlp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import nltk
from nltk.tokenize import sent_tokenize
nltk.download('punkt')

# Read the contents of the file
with open('/content/Untitled document (1).txt', 'r') as file:
    data = file.read()

# Split the text into paragraphs using double newline characters as delimiters
paragraphs = data.split('\n\n')

# Create a DataFrame
df = pd.DataFrame({'Paragraphs': paragraphs})

# Print the DataFrame
df.head()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
#                                           Paragraphs
# 0  ﻿John is a 25-year-old male who enjoys playing...
# 1  \nSarah, a 30-year-old female, is active in va...
# 2  \nAlex, a 22-year-old non-binary individual, p...
# 3  \nMichael, a 40-year-old male, is an avid cycl...
# 4  \nEmily, a 28-year-old female, enjoys hiking a...

# %%
from nltk.tokenize import word_tokenize

df['Tokens'] = df['Paragraphs'].apply(word_tokenize)
print(df)
# Out:
#                                             Paragraphs  \
# 0    ﻿John is a 25-year-old male who enjoys playing...
# 1    \nSarah, a 30-year-old female, is active in va...
# 2    \nAlex, a 22-year-old non-binary individual, p...
# 3    \nMichael, a 40-year-old male, is an avid cycl...
# 4    \nEmily, a 28-year-old female, enjoys hiking a...
# ..                                                 ...
# 425  \nWilliam, a 31-year-old wildlife tour guide, ...
# 426  \nMia, a 28-year-old eco-fashion influencer, p...
# 427  \nOlivia, a 38-year-old sustainability consult...
# 428  \nBenjamin, a 46-year-old eco-architect, desig...
# 429  \nGrace, a 61-year-old retiree, takes pleasure...
#
#                                                 Tokens
# 0    [﻿John, is, a, 25-year-old, male, who, enjoys,...
# 1    [Sarah, ,, a, 30-year-old, female, ,, is, acti...
# 2    [Alex, ,, a, 22-year-old, non-binary, individu...
# 3    [Michael, ,, a, 40-year-old, male, ,, is, an, ...
# 4    [Emily, ,, a, 28-year-old, female, ,, enjoys, ...
# ..                                                 ...
# 425  [William, ,, a, 31-year-old, wildlife, tour, g...
# 426  [Mia, ,, a, 28-year-old, eco-fashion, influenc...
# 427  [Olivia, ,, a, 38-year-old, sustainability, co...
# 428  [Benjamin, ,, a, 46-year-old, eco-architect, ,...
# 429  [Grace, ,, a, 61-year-old, retiree, ,, takes, ...
#
# [430 rows x 2 columns]

# %%
import nltk
import re
from nltk.corpus import stopwords

nltk.download('stopwords')

def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()
    # Remove punctuation and digits
    text = re.sub(r'[^\w\s]', '', text)
    # Remove stopwords
    text = ' '.join([word for word in text.split() if word not in stopwords.words('english')])
    return text

df['Cleaned Paragraphs'] = df['Paragraphs'].apply(preprocess_text)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def remove_first_word(paragraph):
    # Split the paragraph into words
    words = paragraph.split()
    if len(words) > 1:
        # Remove the first word, which is assumed to be the name
        return ' '.join(words[1:])
    else:
        # If there's only one word, return an empty string
        return ''

df['Cleaned Paragraphs'] = df['Cleaned Paragraphs'].apply(remove_first_word)
print(df)
# Out:
#                                             Paragraphs  \
# 0    ﻿John is a 25-year-old male who enjoys playing...
# 1    \nSarah, a 30-year-old female, is active in va...
# 2    \nAlex, a 22-year-old non-binary individual, p...
# 3    \nMichael, a 40-year-old male, is an avid cycl...
# 4    \nEmily, a 28-year-old female, enjoys hiking a...
# ..                                                 ...
# 425  \nWilliam, a 31-year-old wildlife tour guide, ...
# 426  \nMia, a 28-year-old eco-fashion influencer, p...
# 427  \nOlivia, a 38-year-old sustainability consult...
# 428  \nBenjamin, a 46-year-old eco-architect, desig...
# 429  \nGrace, a 61-year-old retiree, takes pleasure...
#
#                                                 Tokens  \
# 0    [﻿John, is, a, 25-year-old, male, who, enjoys,...
# 1    [Sarah, ,, a, 30-year-old, female, ,, is, acti...
# 2    [Alex, ,, a, 22-year-old, non-binary, individu...
# 3    [Michael, ,, a, 40-year-old, male, ,, is, an, ...
# 4    [Emily, ,, a, 28-year-old, female, ,, enjoys, ...
# ..                                                 ...
# 425  [William, ,, a, 31-year-old, wildlife, tour, g...
# 426  [Mia, ,, a, 28-year-old, eco-fashion, influenc...
# 427  [Olivia, ,, a, 38-year-old, sustainability, co...
# 428  [Benjamin, ,, a, 46-year-old, eco-architect, ,...
# 429  [Grace, ,, a, 61-year-old, retiree, ,, takes, ...
#
#                                     Cleaned Paragraphs  \
# 0    male enjoys playing football keeps latest news...
# 1    female active various sports like tennis swimm...
# 2    nonbinary individual participates local soccer...
# 3    male avid cyclist passion sports keeps eye glo...
# 4    female enjoys hiking adventure sports follows ...
# ..                                                 ...
# 425  wildlife tour guide takes groups nature wildli...
# 426  ecofashion influencer promotes sustainable eth...
# 427  sustainability consultant specializes advising...
# 428  ecoarchitect designs environmentally responsib...
# 429  retiree takes pleasure birdwatching nature wal...
#
#                                           Top Keywords  \
# 0         [john, closely, tv, 25yearold, developments]
# 1         [gardener, sarah, swimming, reality, active]
# 2    [22yearold, daily, follow, newspapers, nonbinary]
# 3             [cars, cyclist, michael, eye, 40yearold]
# 4     [online, gourmet, watches, closely, discussions]
# ..                                                 ...
# 425  [william, wildlife, collaborates, fishermen, g...
# 426          [mia, brands, choices, ecofashion, hikes]
# 427  [olivia, advising, carbon, companies, connecting]
# 428  [benjamin, camper, ecoarchitect, harmonize, re...
# 429  [grace, nature, environmentalists, pleasure, r...
#
#                                           Without name
# 0    is a 25-year-old male who enjoys playing footb...
# 1    a 30-year-old female, is active in various spo...
# 2    a 22-year-old non-binary individual, participa...
# 3    a 40-year-old male, is an avid cyclist with a ...
# 4    a 28-year-old female, enjoys hiking and advent...
# ..                                                 ...
# 425  a 31-year-old wildlife tour guide, takes group...
# 426  a 28-year-old eco-fashion influencer, promotes...
# 427  a 38-year-old sustainability consultant, speci...
# 428  a 46-year-old eco-architect, designs environme...
# 429  a 61-year-old retiree, takes pleasure in birdw...
#
# [430 rows x 5 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(df['Cleaned Paragraphs'])

# %%
def extract_top_keywords(tfidf_matrix, tfidf_vectorizer, paragraph, top_n=5):
    tfidf_scores = list(zip(tfidf_vectorizer.get_feature_names_out(), tfidf_matrix[paragraph].toarray()[0]))
    top_keywords = sorted(tfidf_scores, key=lambda x: x[1], reverse=True)[:top_n]
    return [keyword[0] for keyword in top_keywords]

df['Top Keywords'] = [extract_top_keywords(tfidf_matrix, tfidf_vectorizer, i) for i in range(len(df))]
print(df)
# Out:
#                                             Paragraphs  \
# 0    ﻿John is a 25-year-old male who enjoys playing...
# 1    \nSarah, a 30-year-old female, is active in va...
# 2    \nAlex, a 22-year-old non-binary individual, p...
# 3    \nMichael, a 40-year-old male, is an avid cycl...
# 4    \nEmily, a 28-year-old female, enjoys hiking a...
# ..                                                 ...
# 425  \nWilliam, a 31-year-old wildlife tour guide, ...
# 426  \nMia, a 28-year-old eco-fashion influencer, p...
# 427  \nOlivia, a 38-year-old sustainability consult...
# 428  \nBenjamin, a 46-year-old eco-architect, desig...
# 429  \nGrace, a 61-year-old retiree, takes pleasure...
#
#                                                 Tokens  \
# 0    [﻿John, is, a, 25-year-old, male, who, enjoys,...
# 1    [Sarah, ,, a, 30-year-old, female, ,, is, acti...
# 2    [Alex, ,, a, 22-year-old, non-binary, individu...
# 3    [Michael, ,, a, 40-year-old, male, ,, is, an, ...
# 4    [Emily, ,, a, 28-year-old, female, ,, enjoys, ...
# ..                                                 ...
# 425  [William, ,, a, 31-year-old, wildlife, tour, g...
# 426  [Mia, ,, a, 28-year-old, eco-fashion, influenc...
# 427  [Olivia, ,, a, 38-year-old, sustainability, co...
# 428  [Benjamin, ,, a, 46-year-old, eco-architect, ,...
# 429  [Grace, ,, a, 61-year-old, retiree, ,, takes, ...
#
#                                     Cleaned Paragraphs  \
# 0    male enjoys playing football keeps latest news...
# 1    female active various sports like tennis swimm...
# 2    nonbinary individual participates local soccer...
# 3    male avid cyclist passion sports keeps eye glo...
# 4    female enjoys hiking adventure sports follows ...
# ..                                                 ...
# 425  wildlife tour guide takes groups nature wildli...
# 426  ecofashion influencer promotes sustainable eth...
# 427  sustainability consultant specializes advising...
# 428  ecoarchitect designs environmentally responsib...
# 429  retiree takes pleasure birdwatching nature wal...
#
#                                           Top Keywords  \
# 0      [closely, tv, developments, follows, political]
# 1            [gardener, swimming, reality, active, tv]
# 2        [daily, follow, newspapers, nonbinary, reads]
# 3            [cars, cyclist, eye, collecting, vintage]
# 4     [online, gourmet, watches, closely, discussions]
# ..                                                 ...
# 425  [wildlife, collaborates, fishermen, guide, har...
# 426   [brands, choices, ecofashion, hikes, influencer]
# 427  [advising, olivia, carbon, companies, connecting]
# 428  [camper, ecoarchitect, harmonize, reconnecting...
# 429  [nature, environmentalists, pleasure, resident...
#
#                                           Without name
# 0    is a 25-year-old male who enjoys playing footb...
# 1    a 30-year-old female, is active in various spo...
# 2    a 22-year-old non-binary individual, participa...
# 3    a 40-year-old male, is an avid cyclist with a ...
# 4    a 28-year-old female, enjoys hiking and advent...
# ..                                                 ...
# 425  a 31-year-old wildlife tour guide, takes group...
# 426  a 28-year-old eco-fashion influencer, promotes...
# 427  a 38-year-old sustainability consultant, speci...
# 428  a 46-year-old eco-architect, designs environme...
# 429  a 61-year-old retiree, takes pleasure in birdw...
#
# [430 rows x 5 columns]

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

# ... (the rest of your code)

# Define a custom function to perform POS tagging
def pos_tag(text):
    tokens = word_tokenize(text)
    tags = nltk.pos_tag(tokens)
    return [tag[0] for tag in tags if tag[1].startswith('VB')]
# Define a custom function to perform POS tagging
def pos_tag(text):
    tokens = word_tokenize(text)
    tags = nltk.pos_tag(tokens)
    return [tag[0] for tag in tags if tag[1].startswith('VB')]  # Select words with verb POS tags

# Apply POS tagging to the cleaned paragraphs
df['Verbs'] = df['Cleaned Paragraphs'].apply(lambda text: ' '.join(pos_tag(text)))

# Create a custom TF-IDF vectorizer that considers verbs more important
custom_tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = custom_tfidf_vectorizer.fit_transform(df['Cleaned Paragraphs'])

# Extract top keywords with a focus on verbs
def extract_top_keywords_with_verbs(tfidf_matrix, tfidf_vectorizer, paragraph, top_n=5):
    tfidf_scores = list(zip(tfidf_vectorizer.get_feature_names_out(), tfidf_matrix[paragraph].toarray()[0]))
    top_keywords = sorted(tfidf_scores, key=lambda x: x[1], reverse=True)[:top_n]

    # Filter the top keywords to include only those identified as verbs
    top_verbs_keywords = [keyword[0] for keyword in top_keywords if keyword[0] in df['Verbs'][paragraph].split()]

    return top_verbs_keywords

# Extract top keywords with a focus on verbs
df['Top Keywords with Verbs'] = [extract_top_keywords_with_verbs(tfidf_matrix, custom_tfidf_vectorizer, i) for i in range(len(df))]
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
print(df)
# Out:
#                                             Paragraphs  \
# 0    ﻿John is a 25-year-old male who enjoys playing...
# 1    \nSarah, a 30-year-old female, is active in va...
# 2    \nAlex, a 22-year-old non-binary individual, p...
# 3    \nMichael, a 40-year-old male, is an avid cycl...
# 4    \nEmily, a 28-year-old female, enjoys hiking a...
# ..                                                 ...
# 425  \nWilliam, a 31-year-old wildlife tour guide, ...
# 426  \nMia, a 28-year-old eco-fashion influencer, p...
# 427  \nOlivia, a 38-year-old sustainability consult...
# 428  \nBenjamin, a 46-year-old eco-architect, desig...
# 429  \nGrace, a 61-year-old retiree, takes pleasure...
#
#                                                 Tokens  \
# 0    [﻿John, is, a, 25-year-old, male, who, enjoys,...
# 1    [Sarah, ,, a, 30-year-old, female, ,, is, acti...
# 2    [Alex, ,, a, 22-year-old, non-binary, individu...
# 3    [Michael, ,, a, 40-year-old, male, ,, is, an, ...
# 4    [Emily, ,, a, 28-year-old, female, ,, enjoys, ...
# ..                                                 ...
# 425  [William, ,, a, 31-year-old, wildlife, tour, g...
# 426  [Mia, ,, a, 28-year-old, eco-fashion, influenc...
# 427  [Olivia, ,, a, 38-year-old, sustainability, co...
# 428  [Benjamin, ,, a, 46-year-old, eco-architect, ,...
# 429  [Grace, ,, a, 61-year-old, retiree, ,, takes, ...
#
#                                     Cleaned Paragraphs  \
# 0    male enjoys playing football keeps latest news...
# 1    female active various sports like tennis swimm...
# 2    nonbinary individual participates local soccer...
# 3    male avid cyclist passion sports keeps eye glo...
# 4    female enjoys hiking adventure sports follows ...
# ..                                                 ...
# 425  wildlife tour guide takes groups nature wildli...
# 426  ecofashion influencer promotes sustainable eth...
# 427  sustainability consultant specializes advising...
# 428  ecoarchitect designs environmentally responsib...
# 429  retiree takes pleasure birdwatching nature wal...
#
#                                           Top Keywords  \
# 0      [closely, tv, developments, follows, political]
# 1            [gardener, swimming, reality, active, tv]
# 2        [daily, follow, newspapers, nonbinary, reads]
# 3            [cars, cyclist, eye, collecting, vintage]
# 4     [online, gourmet, watches, closely, discussions]
# ..                                                 ...
# 425  [wildlife, collaborates, fishermen, guide, har...
# 426   [brands, choices, ecofashion, hikes, influencer]
# 427  [advising, olivia, carbon, companies, connecting]
# 428  [camper, ecoarchitect, harmonize, reconnecting...
# 429  [nature, environmentalists, pleasure, resident...
#
#                                           Without name  \
# 0    is a 25-year-old male who enjoys playing footb...
# 1    a 30-year-old female, is active in various spo...
# 2    a 22-year-old non-binary individual, participa...
# 3    a 40-year-old male, is an avid cyclist with a ...
# 4    a 28-year-old female, enjoys hiking and advent...
# ..                                                 ...
# 425  a 31-year-old wildlife tour guide, takes group...
# 426  a 28-year-old eco-fashion influencer, promotes...
# 427  a 38-year-old sustainability consultant, speci...
# 428  a 46-year-old eco-architect, designs environme...
# 429  a 61-year-old retiree, takes pleasure in birdw...
#
#                                                  Verbs  \
# 0    enjoys playing keeps follows loves watching sh...
# 1                        stays informed engages enjoys
# 2                               reads volunteer follow
# 3                     keeps enjoys watching collecting
# 4                               enjoys follows engages
# ..                                                 ...
# 425  wildlife takes passionate preserving educating...
# 426              promotes uses takes sharing inspiring
# 427  specializes advising known making reducing enj...
# 428             creating harmonize spends reconnecting
# 429  takes birdwatching passionate live wisdom pres...
#
#        Top Keywords with Verbs
# 0                    [follows]
# 1                           []
# 2              [follow, reads]
# 3                 [collecting]
# 4                           []
# ..                         ...
# 425   [wildlife, collaborates]
# 426                         []
# 427     [advising, connecting]
# 428  [harmonize, reconnecting]
# 429                         []
#
# [430 rows x 7 columns]
